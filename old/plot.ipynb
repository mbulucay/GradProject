# %%
from obspy.core import read

singlechannel = read('./CAVI.BHZ.sac')
print(singlechannel)
singlechannel.plot()
# Out:
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# 1 Trace(s) in Stream:
# KO.CAVI.--.BHZ | 2022-08-02T08:16:55.000000Z - 2022-08-02T08:20:20.990000Z | 100.0 Hz, 20600 samples

# %%
from obspy.core import read

singlechannel = read('./COP.BHZ.DK.2009.050')
print(singlechannel)
singlechannel[0].normalize()
singlechannel.plot()
# Out:
# 1 Trace(s) in Stream:
# DK.COP..BHZ | 2009-02-19T00:00:00.025100Z - 2009-02-19T23:59:59.975100Z | 20.0 Hz, 1728000 samples

# %%
from obspy.core import read
singlechannel = read('./2011-05192010_SILT.BHZ')
print(singlechannel)
singlechannel.plot()
# Out:
# 1 Trace(s) in Stream:
# KO.SILT..BHZ | 2011-05-19T20:10:22.898000Z - 2011-05-19T20:40:22.898000Z | 50.0 Hz, 90001 samples

# %%
singlechannel[0].data
# Out:
# array([-8992., -8976., -8945., ..., -8356., -8281., -8237.], dtype=float32)

# %%
from obspy.core import read
singlechannel = read('./KULA.BHZ2.sac')
print(singlechannel)
singlechannel.plot()
# Out:
# 1 Trace(s) in Stream:
# KO.KULA.--.BHZ | 2022-06-17T16:51:52.000000Z - 2022-06-17T16:57:01.980000Z | 50.0 Hz, 15500 samples

# %%
from obspy.core import read
singlechannel = read('./example_filtered.sac')
print(singlechannel)
singlechannel.plot()
# Out:
# 1 Trace(s) in Stream:
# KO.KULA.--.BHZ | 2022-06-17T16:51:52.000000Z - 2022-06-17T16:57:01.980000Z | 50.0 Hz, 15500 samples

# %%
from obspy.core import read
singlechannel = read('./KULA.BHZ2.sac')
print(singlechannel)
singlechannel.plot()
# Out:
# 1 Trace(s) in Stream:
# KO.KULA.--.BHZ | 2022-06-17T16:51:52.000000Z - 2022-06-17T16:57:01.980000Z | 50.0 Hz, 15500 samples

# %%
from obspy.core import read
singlechannel = read('./example_filtered2.sac')
print(singlechannel)
singlechannel.plot()
# Out:
# 1 Trace(s) in Stream:
# KO.KULA.--.BHZ | 2022-08-17T05:29:54.000000Z - 2022-08-17T05:35:03.980000Z | 50.0 Hz, 15500 samples

# %%
from obspy.core import read
singlechannel = read('./KULAA.BHZ.sac')
print(singlechannel)
singlechannel.plot()
# Out:
# 1 Trace(s) in Stream:
# KO.KULA.--.BHZ | 2022-08-17T05:29:54.000000Z - 2022-08-17T05:35:03.980000Z | 50.0 Hz, 15500 samples

# %%
from obspy.core import read
singlechannel = read('./KULA.BHE.sac')
print(singlechannel)
singlechannel.plot(size=(1600, 600))
# Out:
# 1 Trace(s) in Stream:
# KO.KULA.--.BHE | 2022-08-17T05:29:50.000000Z - 2022-08-17T05:35:09.980000Z | 50.0 Hz, 16000 samples

# %%
from obspy.core import read
singlechannel = read('./KO.KULA..BHE.D.2022.314.094751.SAC')
print(singlechannel)
singlechannel.plot(size=(1600, 600))
# Out:
# 1 Trace(s) in Stream:
# KO.KULA..BHE | 2022-11-10T09:47:51.900000Z - 2022-11-10T09:53:06.800000Z | 50.0 Hz, 15746 samples

# %%
from obspy.core import read
singlechannel = read('./KO.KULA..BHZ.D.2022.314.094754.SAC')
print(singlechannel)
singlechannel.plot(size=(1600, 600))
# Out:
# 1 Trace(s) in Stream:
# KO.KULA..BHZ | 2022-11-10T09:47:54.500000Z - 2022-11-10T09:53:05.720000Z | 50.0 Hz, 15562 samples

# %%
from obspy.core import read
singlechannel = read('.2011-05192010_ADVT.BHZ')
print(singlechannel)
singlechannel.plot(size=(1600, 600))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 from obspy.core import read
# ----> 2 singlechannel = read('./simav_mainshock/2011-05192010_ADVT.BHZ')
#       3 print(singlechannel)
#       4 singlechannel.plot(size=(1600, 600))
#
# File <decorator-gen-49>:2, in read(pathname_or_url, format, headonly, starttime, endtime, nearest_sample, dtype, apply_calib, check_compression, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/obspy/core/util/decorator.py:297, in map_example_filename.<locals>._map_example_filename(func, *args, **kwargs)
#     295                 except IOError:
#     296                     pass
# --> 297 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/obspy/core/stream.py:208, in read(pathname_or_url, format, headonly, starttime, endtime, nearest_sample, dtype, apply_calib, check_compression, **kwargs)
#     206     st = _create_example_stream(headonly=headonly)
#     207 else:
# --> 208     st = _generic_reader(pathname_or_url, _read, **kwargs)
#     210 if len(st) == 0:
#     211     # try to give more specific information why the stream is empty
#     212     if has_magic(pathname_or_url) and not glob(pathname_or_url):
#
# File ~/.local/lib/python3.10/site-packages/obspy/core/util/base.py:656, in _generic_reader(pathname_or_url, callback_func, **kwargs)
#     654         raise Exception("No file matching file pattern: %s" % pathname)
#     655     elif not glob.has_magic(pathname) and not Path(pathname).is_file():
# --> 656         raise IOError(2, "No such file or directory", pathname)
#     658 generic = callback_func(pathnames[0], **kwargs)
#     659 if len(pathnames) > 1:
#
# FileNotFoundError: [Errno 2] No such file or directory: './simav_mainshock/2011-05192010_ADVT.BHZ'

# %%
from obspy.core import read
singlechannel = read('./simav_mainshock/2011-05192010_ANTB.BHZ')
print(singlechannel)
singlechannel.plot(size=(1600, 600))
# Out:
# 1 Trace(s) in Stream:
# KO.ANTB..BHZ | 2011-05-19T20:10:22.898000Z - 2011-05-19T20:40:22.898000Z | 50.0 Hz, 90001 samples

# %%
from obspy.core import read

singlechannel = read('./2011-05192010_CLDR.BHZ')
print(singlechannel)
singlechannel[0].normalize()
singlechannel.plot()
# Out:
# 1 Trace(s) in Stream:
# KO.CLDR..BHZ | 2011-05-19T20:10:22.898000Z - 2011-05-19T20:40:22.898000Z | 50.0 Hz, 90001 samples
