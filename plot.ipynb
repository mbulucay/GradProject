# %%
from obspy.core import read
singlechannel = read('./out.sac')
print(singlechannel)
singlechannel.plot(size=(1600, 600))

# %%
from obspy.core import read
singlechannel = read('./simav_mainshock/2011-05192010_ANTB.BHZ')
print(singlechannel)
singlechannel.plot(size=(1600, 600))
# Out:
# 1 Trace(s) in Stream:
# KO.ADVT..BHZ | 2011-05-19T20:10:22.898000Z - 2011-05-19T20:40:22.898000Z | 50.0 Hz, 90001 samples
