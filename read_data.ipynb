# %%
from obspy.core import read
singlechannel = read('./19991107165448_5401_ap_Acc.mseed')
print(singlechannel)
singlechannel.plot(size=(1600, 600))

# %%
from obspy.core import read
singlechannel = read('./19990817000139_1404_mp_Acc_N.asc')
print(singlechannel)
singlechannel.plot(size=(1600, 600))
