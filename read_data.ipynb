# %%
from obspy.core import read
singlechannel = read('./19991107165448_5401_ap_Acc.mseed')
print(singlechannel)
singlechannel.plot(size=(1600, 600))
# Out:
# 3 Trace(s) in Stream:
# TK.5401..E | 1999-11-07T16:54:48.000000Z - 1999-11-07T16:56:23.720000Z | 100.0 Hz, 9573 samples
# TK.5401..N | 1999-11-07T16:54:48.000000Z - 1999-11-07T16:56:23.720000Z | 100.0 Hz, 9573 samples
# TK.5401..Z | 1999-11-07T16:54:48.000000Z - 1999-11-07T16:56:23.720000Z | 100.0 Hz, 9573 samples

# %%
from obspy.core import read
singlechannel = read('./old/example_filtered2.sac')
print(singlechannel)
singlechannel.plot()
# Out:
# 1 Trace(s) in Stream:
# KO.KULA.--.BHZ | 2022-08-17T05:29:54.000000Z - 2022-08-17T05:35:03.980000Z | 50.0 Hz, 15500 samples
