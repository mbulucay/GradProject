# %%
# Import the clean_sac_file function from the previous example
from obspy import read, Trace, Stream
from obspy.signal.filter import bandpass
import numpy as np

def clean_sac_file(input_file, output_file, freq_min = 2.0, freq_max = 4.3, time_pad = 10.001):
    """
    Applies a bandpass filter to a SAC file to clean noise.
    Inputs:
    - input_file: path to the input SAC file
    - output_file: path to the output SAC file
    - freq_min: minimum frequency of the passband in Hz
    - freq_max: maximum frequency of the passband in Hz
    """
    # Read in the SAC file as an ObsPy Trace object
    trace = read(input_file)[0]
    # trace.plot()
    
    # Apply a bandpass filter to the trace
    trace_filtered = trace.copy()
    t = trace_filtered.stats.starttime

    if t + time_pad > trace_filtered.stats.endtime:
        return None
    
    trace_filtered = trace_filtered.trim(t + time_pad, trace_filtered.stats.endtime) 
    # trace_filtered = trace_filtered.trim(t, trace_filtered.stats.endtime)
    # trace_filtered.data = np.concatenate((np.zeros(750), trace_filtered.data))
    
    trace_filtered.data = bandpass(trace_filtered.data, freqmin=freq_min, freqmax=freq_max, df=trace_filtered.stats.sampling_rate)
    # trace_filtered = trace_filtered.trim(t + time_pad, trace_filtered.stats.endtime)
    # trace_filtered.plot()

    return trace_filtered
# Out:
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(

# %%
import os
import shutil
from obspy import read, Trace, Stream

os.makedirs("class0") # yok
os.makedirs("class1") # 1 seviye 250
os.makedirs("class2") # 2 seviye 500
os.makedirs("class3") # 3 seviye 1000
os.makedirs("class4") # 4 seviye 2000
os.makedirs("class5") # 5 seviye 4000
os.makedirs("class6") # 6 seviye 8000   
os.makedirs("class7") # 6 seviye 16000   
os.makedirs("class8") # 6 seviye 32000   


# Define the directory path
dir_path = './'
orderdata = '202009_'

c = 0

clean_files = []

for i, folder_month in enumerate(os.listdir(dir_path)):

    if not os.path.isfile(dir_path + folder_month):
        # print(folder_month)

        for j, eartq in enumerate(os.listdir(dir_path + folder_month)):

            if not os.path.join(dir_path, folder_month, eartq).format().__contains__("BHZ"):
                continue

            # print(f"    {eartq}")
            
            date = str(i) + "_" + str(j) + "_"
            
            # c = c + 1
            # continue

            # Define the input and output file paths
            input_file = dir_path + folder_month + '/' + eartq
            output_file = orderdata + date + eartq.replace('(', '').replace(')', '').replace('=', '').replace('KO', 'SAC')


            file_name = dir_path + folder_month + '/' + eartq


            if clean_files.__contains__(file_name):
                continue

            trace_filtered = clean_sac_file(input_file, output_file)
            if trace_filtered is None:
                continue

            clean_files.append(file_name)

            # if trace_filtered.stast.endtime - trace_filtered.stats.starttime < 15:
            #     continue

            min_val = min(trace_filtered.data[150:])
            max_val = max(trace_filtered.data[300:])

            max_value_index = np.argmax(trace_filtered.data[300:])
            # get the 1000 padding centered max index
            trace_filtered.data = trace_filtered.data[max_value_index - 2000: max_value_index + 2000]
           
            # print(f"min: {min_val} max: {max_val}")
            # print(file_name)
            # if max_val > 16000:
            #     trace_filtered.write('./class6/' + output_file, format='SAC')
            #     # shutil.copy(file_name, './class6/' + eartq + '_original.sac')

            if max_val < 250:
                trace_filtered.write('./class0/' + output_file, format='SAC')
                # shutil.copy(file_name, './class0/' + eartq + '_original.sac')
            elif max_val < 500:
                trace_filtered.write('./class1/' + output_file, format='SAC')
                # shutil.copy(file_name, './class1/' + eartq + '_original.sac')
            elif max_val < 1000:
                trace_filtered.write('./class2/' + output_file, format='SAC')
                # shutil.copy(file_name, './class2/' + eartq + '_original.sac')
            elif max_val < 2000:
                trace_filtered.write('./class3/' + output_file, format='SAC')
                # shutil.copy(file_name, './class3/' + eartq + '_original.sac')
            elif max_val < 4000:
                trace_filtered.write('./class4/' + output_file, format='SAC')
                # shutil.copy(file_name, './class4/' + eartq + '_original.sac')
            elif max_val < 8000:
                trace_filtered.write('./class5/' + output_file, format='SAC')
                # shutil.copy(file_name, './class5/' + eartq + '_original.sac')
            elif max_val < 16000:
                trace_filtered.write('./class6/' + output_file, format='SAC')
                # shutil.copy(file_name, './class6/' + eartq + '_original.sac')
            elif max_val < 32000:
                trace_filtered.write('./class7/' + output_file, format='SAC')
                # shutil.copy(file_name, './class7/' + eartq + '_original.sac')
            else:
                trace_filtered.write('./class8/' + output_file, format='SAC')
                # shutil.copy(file_name, './class8/' + eartq + '_original.sac')



            # if max_val < 500:
            #     trace_filtered.write('./class0/' + output_file, format='SAC')
            #     # shutil.copy(file_name, './class0/' + eartq + '_original.sac')
            # elif max_val < 1000:
            #     trace_filtered.write('./class1/' + output_file, format='SAC')
            #     # shutil.copy(file_name, './class1/' + eartq + '_original.sac')
            # elif max_val < 2000:
            #     trace_filtered.write('./class2/' + output_file, format='SAC')
            #     # shutil.copy(file_name, './class2/' + eartq + '_original.sac')
            # elif max_val < 4000:
            #     trace_filtered.write('./class3/' + output_file, format='SAC')
            #     # shutil.copy(file_name, './class3/' + eartq + '_original.sac')
            # elif max_val < 8000:
            #     trace_filtered.write('./class4/' + output_file, format='SAC')
            #     # shutil.copy(file_name, './class4/' + eartq + '_original.sac')
            # elif max_val < 16000:
            #     trace_filtered.write('./class5/' + output_file, format='SAC')
            #     # shutil.copy(file_name, './class5/' + eartq + '_original.sac')
            # else:
            #     trace_filtered.write('./class6/' + output_file, format='SAC')
            #     # shutil.copy(file_name, './class6/' + eartq + '_original.sac')

print(c)
# Out:
# 0

# %%
#  read sac file

from obspy import read, Trace, Stream
import os

path = "./"
folder_classes = ["class8", "class7", "class6", "class5", "class4", "class3", "class2", "class1", "class0"]

for folder_class in folder_classes:
    files = []
    for j, file in enumerate(os.listdir(path= path + folder_class)):
        files.append(file)

    files = sorted(files)

    for i, file in enumerate(files):
        print(file)
        trace = read(path + folder_class + "/" + file)[0]
        print(len(trace.data))

        if len(trace.data) == 4000:
            print(trace.stats)
            # trace.plot()
            # ix = input("Press Enter to continue...")
            # if ix == 'q':
            #     break
        else:
            os.remove(path + folder_class + "/" + file)
# Out:
# 202009_19_4_SIMA.BHZ.SAC
# 0
# 202009_22_5_SIMA.BHZ.SAC
# 4000
#          network: KO
#          station: SIMA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:07.000000Z
#          endtime: 2020-09-10T20:17:26.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -19017.146, 'depmax': 18495.459, 'b': 10.0, 'e': 89.979996, 'o': 3.0, 'a': 127.14, 'internal0': 2.0, 't0': 130.093, 't1': 2.953003, 'f': 0.0, 'stla': 39.0833, 'stlo': 28.9825, 'stel': 984.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 14.525864, 'az': 141.2083, 'baz': 321.27438, 'gcarc': 0.13065684, 'depmen': -0.036924377, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 57, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'SIMA', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_2_3_SIMA.BHZ.SAC
# 0
# 202009_14_0_SIMA.BHZ.SAC
# 0
# 202009_1_0_SIMA.BHZ.SAC
# 0
# 202009_20_0_SIMA.BHZ.SAC
# 0
# 202009_19_11_AYDB.BHZ.SAC
# 0
# 202009_19_46_GEDZ.BHZ.SAC
# 4000
#          network: KO
#          station: GEDZ
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:52.000000Z
#          endtime: 2020-09-19T20:38:31.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -5167.0913, 'depmax': 5395.6367, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 75.318, 'internal0': 2.0, 't0': 79.936, 't1': 4.617996, 'f': 0.0, 'stla': 39.0445, 'stlo': 29.4105, 'stel': 883.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 35.428944, 'az': 110.48915, 'baz': 290.7299, 'gcarc': 0.31867468, 'depmen': -0.59622943, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 42, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'GEDZ', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'IPx12', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_20_11_GEDZ.BHZ.SAC
# 4000
#          network: KO
#          station: GEDZ
#         location: --
#          channel: BHZ
#        starttime: 2020-09-11T00:34:51.000000Z
#          endtime: 2020-09-11T00:35:30.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -4735.994, 'depmax': 4288.7856, 'b': 10.0, 'e': 49.989998, 'o': 4.0, 'a': 96.344, 'internal0': 2.0, 't0': 101.85, 't1': 5.5059967, 'f': 0.0, 'stla': 39.0445, 'stlo': 29.4105, 'stel': 883.0, 'evla': 38.9665, 'evlo': 28.9585, 'evdp': 5.3, 'dist': 40.100716, 'az': 77.38787, 'baz': 257.67117, 'gcarc': 0.36069414, 'depmen': -0.0627939, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 255, 'nzhour': 0, 'nzmin': 34, 'nzsec': 41, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'GEDZ', 'kevnm': '20200911003528', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_0_0_SIMA.BHZ.SAC
# 0
# 202009_10_79_SAC.SIMA..BHZ.D.2020.255.203759.SAC
# 0
# 202009_11_0_SIMA.BHZ.SAC
# 0
# 202009_12_2_SIMA.BHZ.SAC
# 4000
#          network: KO
#          station: SIMA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-11T20:37:07.000000Z
#          endtime: 2020-09-11T20:38:26.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -3440.262, 'depmax': 3094.2065, 'b': 10.0, 'e': 89.979996, 'o': 3.0, 'a': 134.42, 'internal0': 2.0, 't0': 136.486, 't1': 2.0659943, 'f': 0.0, 'stla': 39.0833, 'stlo': 28.9825, 'stel': 984.0, 'evla': 39.17667, 'evlo': 28.892, 'evdp': 6.7, 'dist': 12.988168, 'az': 142.91986, 'baz': 322.9767, 'gcarc': 0.11682559, 'depmen': -0.012101021, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 255, 'nzhour': 20, 'nzmin': 36, 'nzsec': 57, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'SIMA', 'kevnm': '20200911203811', 'khole': '--', 'ko': 'origin', 'ka': 'EPU22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_16_0_SIMA.BHZ.SAC
# 0
# 202009_21_0_SIMA.BHZ.SAC
# 4000
#          network: KO
#          station: SIMA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-20T23:42:03.000000Z
#          endtime: 2020-09-20T23:43:22.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -3136.4573, 'depmax': 2924.8367, 'b': 10.0, 'e': 89.979996, 'o': 7.0, 'a': 192.38, 'internal0': 2.0, 't0': 193.986, 't1': 1.6059875, 'f': 0.0, 'stla': 39.0833, 'stlo': 28.9825, 'stel': 984.0, 'evla': 39.14667, 'evlo': 29.01483, 'evdp': 13.4, 'dist': 7.570607, 'az': 201.68597, 'baz': 21.665684, 'gcarc': 0.06809581, 'depmen': -0.0016987784, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 264, 'nzhour': 23, 'nzmin': 41, 'nzsec': 53, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'SIMA', 'kevnm': '20200920234409', 'khole': '--', 'ko': 'origin', 'ka': 'EPx22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_79_TVSB.BHZ.SAC
# 4000
#          network: KO
#          station: TVSB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:09.000000Z
#          endtime: 2020-09-10T20:16:48.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -1893.3458, 'depmax': 2028.1721, 'b': 10.0, 'e': 49.989998, 'o': 1.0, 'a': 134.35, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 39.4497, 'stlo': 29.4615, 'stel': 1090.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 58.30703, 'az': 59.5914, 'baz': 239.96002, 'gcarc': 0.524464, 'depmen': 0.10832167, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 59, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'TVSB', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPU32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_2_30_GEDZ.BHZ.SAC
# 4000
#          network: KO
#          station: GEDZ
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:40:12.000000Z
#          endtime: 2020-09-19T20:40:51.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -2170.0806, 'depmax': 2534.1992, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 104.828, 'internal0': 2.0, 't0': 109.47, 't1': 4.6419983, 'f': 0.0, 'stla': 39.0445, 'stlo': 29.4105, 'stel': 883.0, 'evla': 39.141, 'evlo': 29.0235, 'evdp': 7.6, 'dist': 35.15493, 'az': 107.62141, 'baz': 287.8644, 'gcarc': 0.31620985, 'depmen': -0.056056194, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 40, 'nzsec': 2, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'GEDZ', 'kevnm': '20200919204037', 'khole': '--', 'ko': 'origin', 'ka': 'EPx22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_5_0_202009_2_30_GEDZ.BHZ.SAC
# 1000
# 202009_9_0_SIMA.BHZ.SAC
# 0
# 202009_19_16_KULA.BHZ.SAC
# 0
# 202009_19_58_TVSB.BHZ.SAC
# 4000
#          network: KO
#          station: TVSB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:52.000000Z
#          endtime: 2020-09-19T20:38:31.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -1192.2979, 'depmax': 1237.92, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 76.876, 'internal0': 2.0, 't0': 82.94, 't1': 6.064003, 'f': 0.0, 'stla': 39.4497, 'stlo': 29.4615, 'stel': 1090.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 49.607655, 'az': 48.909565, 'baz': 229.18355, 'gcarc': 0.4462139, 'depmen': -0.051702287, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 42, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'TVSB', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPx22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_19_62_ARMT.BHZ.SAC
# 4000
#          network: KO
#          station: ARMT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:45.000000Z
#          endtime: 2020-09-19T20:38:24.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -1239.1235, 'depmax': 1534.8491, 'b': 10.0, 'e': 49.989998, 'o': 10.0, 'a': 94.911, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.5683, 'stlo': 28.866, 'stel': 320.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 157.32655, 'az': 355.02225, 'baz': 174.91936, 'gcarc': 1.4151762, 'depmen': -0.15302812, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 35, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'ARMT', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_0_BALB.BHZ.SAC
# 4000
#          network: KO
#          station: BALB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:06.000000Z
#          endtime: 2020-09-10T20:16:45.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -939.3613, 'depmax': 1037.1963, 'b': 10.0, 'e': 49.989998, 'o': 4.0, 'a': 142.239, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 39.6507, 'stlo': 27.8642, 'stel': 266.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 101.40063, 'az': 300.95264, 'baz': 120.311935, 'gcarc': 0.9120904, 'depmen': -0.013084194, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 56, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'BALB', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EP+32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_116_MDNY.BHZ.SAC
# 4000
#          network: KO
#          station: MDNY
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:07.000000Z
#          endtime: 2020-09-10T20:16:46.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -2123.4285, 'depmax': 1793.8973, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 147.367, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.371, 'stlo': 28.8847, 'stel': 116.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 131.64914, 'az': 0.2724642, 'baz': 180.27715, 'gcarc': 1.184198, 'depmen': -0.117176995, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 57, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'MDNY', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_135_GULT.BHZ.SAC
# 4000
#          network: KO
#          station: GULT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:05.000000Z
#          endtime: 2020-09-10T20:16:44.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -1157.314, 'depmax': 1244.9531, 'b': 10.0, 'e': 49.989998, 'o': 5.0, 'a': 156.139, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.432, 'stlo': 30.5156, 'stel': 942.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 197.08087, 'az': 44.865723, 'baz': 225.91046, 'gcarc': 1.7727666, 'depmen': -0.75403214, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 55, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'GULT', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_26_KULA.BHZ.SAC
# 4000
#          network: KO
#          station: KULA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:15:53.000000Z
#          endtime: 2020-09-10T20:17:12.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -2013.3496, 'depmax': 1856.2383, 'b': 10.0, 'e': 89.979996, 'o': 17.0, 'a': 137.705, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 38.5145, 'stlo': 28.6607, 'stel': 915.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 76.80966, 'az': 194.24065, 'baz': 14.105334, 'gcarc': 0.69087416, 'depmen': 0.034933213, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 43, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KULA', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_57_KCTX.BHZ.SAC
# 4000
#          network: KO
#          station: KCTX
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:07.000000Z
#          endtime: 2020-09-10T20:16:46.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -1277.5088, 'depmax': 1481.9468, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 146.827, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.2627, 'stlo': 28.3353, 'stel': 445.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 128.33194, 'az': 338.94016, 'baz': 158.59514, 'gcarc': 1.1543559, 'depmen': -0.037117563, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 57, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KCTX', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EP-32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_82_ARMT.BHZ.SAC
# 4000
#          network: KO
#          station: ARMT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:04.000000Z
#          endtime: 2020-09-10T20:16:43.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -1743.057, 'depmax': 1882.989, 'b': 10.0, 'e': 49.989998, 'o': 6.0, 'a': 150.606, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.5683, 'stlo': 28.866, 'stel': 320.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 153.56001, 'az': 359.64188, 'baz': 179.63467, 'gcarc': 1.3812966, 'depmen': 0.21133666, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 54, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'ARMT', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EP-32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_12_17_GEDZ.BHZ.SAC
# 4000
#          network: KO
#          station: GEDZ
#         location: --
#          channel: BHZ
#        starttime: 2020-09-11T20:37:08.000000Z
#          endtime: 2020-09-11T20:37:47.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -750.253, 'depmax': 717.2074, 'b': 10.0, 'e': 49.989998, 'o': 2.0, 'a': 140.077, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 39.0445, 'stlo': 29.4105, 'stel': 883.0, 'evla': 39.17667, 'evlo': 28.892, 'evdp': 6.7, 'dist': 47.188076, 'az': 107.9541, 'baz': 288.27982, 'gcarc': 0.42444542, 'depmen': 0.09132529, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 255, 'nzhour': 20, 'nzmin': 36, 'nzsec': 58, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'GEDZ', 'kevnm': '20200911203811', 'khole': '--', 'ko': 'origin', 'ka': 'EPx22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_15_1_SIMA.BHZ.SAC
# 4000
#          network: KO
#          station: SIMA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-26T18:18:03.000000Z
#          endtime: 2020-09-26T18:19:22.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -1164.422, 'depmax': 926.98004, 'b': 10.0, 'e': 89.979996, 'o': 7.0, 'a': 108.892, 'internal0': 2.0, 't0': 115.257, 't1': 6.3650055, 'f': 0.0, 'stla': 39.0833, 'stlo': 28.9825, 'stel': 984.0, 'evla': 39.51833, 'evlo': 28.9315, 'evdp': 5.3, 'dist': 48.498123, 'az': 174.77916, 'baz': 354.8113, 'gcarc': 0.43623376, 'depmen': -0.021456474, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 270, 'nzhour': 18, 'nzmin': 17, 'nzsec': 53, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'SIMA', 'kevnm': '20200926181839', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_15_21_GEDZ.BHZ.SAC
# 3188
# 202009_15_2_GEML.BHZ.SAC
# 4000
#          network: KO
#          station: GEML
#         location: --
#          channel: BHZ
#        starttime: 2020-09-26T18:18:07.000000Z
#          endtime: 2020-09-26T18:18:46.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -513.49786, 'depmax': 697.12634, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 119.156, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.4646, 'stlo': 29.2116, 'stel': 222.0, 'evla': 39.51833, 'evlo': 28.9315, 'evdp': 5.3, 'dist': 107.75945, 'az': 12.7374525, 'baz': 192.91673, 'gcarc': 0.96931976, 'depmen': 0.17249218, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 270, 'nzhour': 18, 'nzmin': 17, 'nzsec': 57, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'GEML', 'kevnm': '20200926181839', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_15_33_ARMT.BHZ.SAC
# 4000
#          network: KO
#          station: ARMT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-26T18:18:08.000000Z
#          endtime: 2020-09-26T18:18:47.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -679.5957, 'depmax': 604.017, 'b': 10.0, 'e': 49.989998, 'o': 2.0, 'a': 120.114, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.5683, 'stlo': 28.866, 'stel': 320.0, 'evla': 39.51833, 'evlo': 28.9315, 'evdp': 5.3, 'dist': 116.71985, 'az': 357.2758, 'baz': 177.23383, 'gcarc': 1.0499235, 'depmen': 0.040243234, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 270, 'nzhour': 18, 'nzmin': 17, 'nzsec': 58, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'ARMT', 'kevnm': '20200926181839', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_15_45_MDNY.BHZ.SAC
# 4000
#          network: KO
#          station: MDNY
#         location: --
#          channel: BHZ
#        starttime: 2020-09-26T18:18:05.000000Z
#          endtime: 2020-09-26T18:18:44.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -756.2443, 'depmax': 759.2768, 'b': 10.0, 'e': 49.989998, 'o': 5.0, 'a': 116.645, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.371, 'stlo': 28.8847, 'stel': 116.0, 'evla': 39.51833, 'evlo': 28.9315, 'evdp': 5.3, 'dist': 94.761024, 'az': 357.5958, 'baz': 177.56589, 'gcarc': 0.85239375, 'depmen': 0.14610305, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 270, 'nzhour': 18, 'nzmin': 17, 'nzsec': 55, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'MDNY', 'kevnm': '20200926181839', 'khole': '--', 'ko': 'origin', 'ka': 'EPU33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_19_0_BALB.BHZ.SAC
# 4000
#          network: KO
#          station: BALB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:52.000000Z
#          endtime: 2020-09-19T20:38:31.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -572.7397, 'depmax': 692.833, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 87.957, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 39.6507, 'stlo': 27.8642, 'stel': 266.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 114.1987, 'az': 299.06122, 'baz': 118.32597, 'gcarc': 1.0272073, 'depmen': 0.1724396, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 42, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'BALB', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EP-32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_19_39_KCTX.BHZ.SAC
# 4000
#          network: KO
#          station: KCTX
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:52.000000Z
#          endtime: 2020-09-19T20:38:31.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -685.0003, 'depmax': 768.9189, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 91.693, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.2627, 'stlo': 28.3353, 'stel': 445.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 136.36942, 'az': 334.42792, 'baz': 153.98767, 'gcarc': 1.2266526, 'depmen': 0.17482217, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 42, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KCTX', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_19_6_GEML.BHZ.SAC
# 4000
#          network: KO
#          station: GEML
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:54.000000Z
#          endtime: 2020-09-19T20:38:33.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -571.1567, 'depmax': 611.225, 'b': 10.0, 'e': 49.989998, 'o': 1.0, 'a': 93.401, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.4646, 'stlo': 29.2116, 'stel': 222.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 146.06186, 'az': 6.148815, 'baz': 186.2664, 'gcarc': 1.3138446, 'depmen': -0.08417959, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 44, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'GEML', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_19_97_GULT.BHZ.SAC
# 4000
#          network: KO
#          station: GULT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:51.000000Z
#          endtime: 2020-09-19T20:38:30.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -554.2319, 'depmax': 594.5777, 'b': 10.0, 'e': 49.989998, 'o': 4.0, 'a': 99.165, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.432, 'stlo': 30.5156, 'stel': 942.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 190.5207, 'az': 41.529404, 'baz': 222.4783, 'gcarc': 1.7137557, 'depmen': 0.19529927, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 41, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'GULT', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_117_ADVT.BHZ.SAC
# 4000
#          network: KO
#          station: ADVT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:00.000000Z
#          endtime: 2020-09-10T20:16:39.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -558.03186, 'depmax': 565.4961, 'b': 10.0, 'e': 49.989998, 'o': 10.0, 'a': 151.146, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.4332, 'stlo': 29.7383, 'stel': 193.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 156.94887, 'az': 27.745613, 'baz': 208.29465, 'gcarc': 1.4117744, 'depmen': 0.038432583, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 50, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'ADVT', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EP-32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_81_SHUT.BHZ.SAC
# 4000
#          network: KO
#          station: SHUT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:03.000000Z
#          endtime: 2020-09-10T20:17:22.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -555.6925, 'depmax': 536.91956, 'b': 10.0, 'e': 89.979996, 'o': 7.0, 'a': 151.416, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 38.553, 'stlo': 30.551, 'stel': 1215.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 161.32901, 'az': 115.26768, 'baz': 296.3137, 'gcarc': 1.4510956, 'depmen': -0.0016917959, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 53, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'SHUT', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_96_BLCB.BHZ.SAC
# 4000
#          network: KO
#          station: BLCB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:06.000000Z
#          endtime: 2020-09-10T20:17:25.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -1049.7786, 'depmax': 944.08417, 'b': 10.0, 'e': 89.979996, 'o': 4.0, 'a': 154.384, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 38.3853, 'stlo': 27.042, 'stel': 150.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 182.53513, 'az': 241.46118, 'baz': 60.3162, 'gcarc': 1.6418289, 'depmen': -0.017777285, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 56, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'BLCB', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_98_EDC.BHZ.SAC
# 4000
#          network: KO
#          station: EDC
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:06.000000Z
#          endtime: 2020-09-10T20:16:45.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -604.8024, 'depmax': 548.4625, 'b': 10.0, 'e': 49.989998, 'o': 4.0, 'a': 150.876, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.3465, 'stlo': 27.8618, 'stel': 257.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 155.54448, 'az': 326.3044, 'baz': 145.65741, 'gcarc': 1.3991382, 'depmen': -0.080378465, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 56, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'EDC', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_10_129_SAC.DKL..BHZ.D.2020.255.203755.SAC
# 4000
#          network: KO
#          station: DKL
#         location:
#          channel: BHZ
#        starttime: 2020-09-11T20:38:05.960000Z
#          endtime: 2020-09-11T20:39:25.940000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -305.8424, 'depmax': 299.6299, 'b': 10.0, 'e': 89.979996, 'a': -0.0143125, 'internal0': 0.90849996, 't0': 0.002, 't1': 0.002, 'f': 0.0, 'stla': 39.0713, 'stlo': 26.9053, 'stel': 35.0, 'evla': 0.0, 'evlo': 0.0, 'evdp': 0.0, 'dist': 5123.1626, 'az': 29.300737, 'baz': 218.95251, 'gcarc': 46.037453, 'depmen': -0.0050946223, 'nzyear': 2020, 'nzjday': 255, 'nzhour': 20, 'nzmin': 37, 'nzsec': 55, 'nzmsec': 960, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'leven': 1, 'lpspol': 0, 'lovrok': 1, 'lcalda': 1, 'kstnm': 'DKL', 'kevnm': '20200911203809', 'ka': 'EP-22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_10_34_GE.ISP.00.BHZ.D.2020.255.203753.SAC
# 2595
# 202009_10_55_SAC.KULA..BHZ.D.2020.255.203754.SAC
# 0
# 202009_12_4_KULA.BHZ.SAC
# 4000
#          network: KO
#          station: KULA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-11T20:36:51.000000Z
#          endtime: 2020-09-11T20:38:10.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -539.19214, 'depmax': 469.96597, 'b': 10.0, 'e': 89.979996, 'o': 19.0, 'a': 144.822, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 38.5145, 'stlo': 28.6607, 'stel': 915.0, 'evla': 39.17667, 'evlo': 28.892, 'evdp': 6.7, 'dist': 76.20387, 'az': 195.35155, 'baz': 15.207088, 'gcarc': 0.6854251, 'depmen': 0.0033597192, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 255, 'nzhour': 20, 'nzmin': 36, 'nzsec': 41, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KULA', 'kevnm': '20200911203811', 'khole': '--', 'ko': 'origin', 'ka': 'EPx22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_15_53_GULT.BHZ.SAC
# 4000
#          network: KO
#          station: GULT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-26T18:18:07.000000Z
#          endtime: 2020-09-26T18:18:46.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -305.35083, 'depmax': 291.6962, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 128.147, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.432, 'stlo': 30.5156, 'stel': 942.0, 'evla': 39.51833, 'evlo': 28.9315, 'evdp': 5.3, 'dist': 169.12971, 'az': 52.63816, 'baz': 233.65186, 'gcarc': 1.5213572, 'depmen': -0.05340183, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 270, 'nzhour': 18, 'nzmin': 17, 'nzsec': 57, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'GULT', 'kevnm': '20200926181839', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_15_5_KULA.BHZ.SAC
# 4000
#          network: KO
#          station: KULA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-26T18:17:59.000000Z
#          endtime: 2020-09-26T18:19:18.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -319.339, 'depmax': 334.88358, 'b': 10.0, 'e': 89.979996, 'o': 11.0, 'a': 119.89, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 38.5145, 'stlo': 28.6607, 'stel': 915.0, 'evla': 39.51833, 'evlo': 28.9315, 'evdp': 5.3, 'dist': 113.88401, 'az': 191.9702, 'baz': 11.800431, 'gcarc': 1.0243539, 'depmen': 0.0027662774, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 270, 'nzhour': 18, 'nzmin': 17, 'nzsec': 49, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KULA', 'kevnm': '20200926181839', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_19_15_CAVI.BHZ.SAC
# 4000
#          network: KO
#          station: CAVI
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:45.000000Z
#          endtime: 2020-09-19T20:38:24.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -559.8088, 'depmax': 418.27243, 'b': 10.0, 'e': 49.989998, 'o': 10.0, 'a': 91.788, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.2018, 'stlo': 29.8377, 'stel': 670.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 135.2667, 'az': 30.680428, 'baz': 211.19586, 'gcarc': 1.2167313, 'depmen': 0.05324754, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 35, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'CAVI', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPD32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_19_2_YAYO.BHZ.SAC
# 4000
#          network: KO
#          station: YAYO
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:52.000000Z
#          endtime: 2020-09-19T20:38:31.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -320.2815, 'depmax': 384.42792, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 96.924, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 39.6114, 'stlo': 27.0726, 'stel': 122.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 175.8046, 'az': 287.29837, 'baz': 106.06314, 'gcarc': 1.5813451, 'depmen': 0.000544239, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 42, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'YAYO', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_19_61_SHUT.BHZ.SAC
# 4000
#          network: KO
#          station: SHUT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:45.000000Z
#          endtime: 2020-09-19T20:39:04.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -287.273, 'depmax': 327.7956, 'b': 10.0, 'e': 89.979996, 'o': 10.0, 'a': 93.295, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 38.553, 'stlo': 30.551, 'stel': 1215.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 148.29407, 'az': 116.39607, 'baz': 297.34814, 'gcarc': 1.3338499, 'depmen': -0.013365398, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 35, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'SHUT', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_19_73_EDC.BHZ.SAC
# 4000
#          network: KO
#          station: EDC
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:53.000000Z
#          endtime: 2020-09-19T20:38:32.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -386.92075, 'depmax': 417.89987, 'b': 10.0, 'e': 49.989998, 'o': 2.0, 'a': 95.691, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.3465, 'stlo': 27.8618, 'stel': 257.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 165.59966, 'az': 323.2747, 'baz': 142.53246, 'gcarc': 1.4895843, 'depmen': 0.12939572, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 43, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'EDC', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_20_28_MDNY.BHZ.SAC
# 4000
#          network: KO
#          station: MDNY
#         location: --
#          channel: BHZ
#        starttime: 2020-09-11T00:34:52.000000Z
#          endtime: 2020-09-11T00:35:31.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -309.2754, 'depmax': 264.6698, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 115.313, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.371, 'stlo': 28.8847, 'stel': 116.0, 'evla': 38.9665, 'evlo': 28.9585, 'evdp': 5.3, 'dist': 156.07037, 'az': 357.6979, 'baz': 177.65102, 'gcarc': 1.4038608, 'depmen': 0.10747251, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 255, 'nzhour': 0, 'nzmin': 34, 'nzsec': 42, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'MDNY', 'kevnm': '20200911003528', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_20_2_KULA.BHZ.SAC
# 4000
#          network: KO
#          station: KULA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-11T00:34:37.000000Z
#          endtime: 2020-09-11T00:35:56.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -224.0936, 'depmax': 277.72293, 'b': 10.0, 'e': 89.979996, 'o': 18.0, 'a': 98.972, 'internal0': 2.0, 't0': 106.405, 't1': 7.4329987, 'f': 0.0, 'stla': 38.5145, 'stlo': 28.6607, 'stel': 915.0, 'evla': 38.9665, 'evlo': 28.9585, 'evdp': 5.3, 'dist': 56.464325, 'az': 207.38791, 'baz': 27.202343, 'gcarc': 0.5078723, 'depmen': 0.02415696, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 255, 'nzhour': 0, 'nzmin': 34, 'nzsec': 27, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KULA', 'kevnm': '20200911003528', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_25_CAVI.BHZ.SAC
# 4000
#          network: KO
#          station: CAVI
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:00.000000Z
#          endtime: 2020-09-10T20:16:39.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -376.2556, 'depmax': 375.15936, 'b': 10.0, 'e': 49.989998, 'o': 10.0, 'a': 148.717, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.2018, 'stlo': 29.8377, 'stel': 670.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 139.72557, 'az': 35.82266, 'baz': 216.43358, 'gcarc': 1.2568402, 'depmen': 0.01908685, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 50, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'CAVI', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_27_YLV.BHZ.SAC
# 4000
#          network: KO
#          station: YLV
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:04.000000Z
#          endtime: 2020-09-10T20:16:43.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -272.05145, 'depmax': 323.6331, 'b': 10.0, 'e': 49.989998, 'o': 6.0, 'a': 151.339, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.5658, 'stlo': 29.3708, 'stel': 879.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 158.98657, 'az': 15.242264, 'baz': 195.55737, 'gcarc': 1.4301093, 'depmen': -0.01601685, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 54, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'YLV', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EP-32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_85_SDAG.BHZ.SAC
# 4000
#          network: KO
#          station: SDAG
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:09.000000Z
#          endtime: 2020-09-10T20:16:48.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -204.29462, 'depmax': 260.42047, 'b': 10.0, 'e': 49.989998, 'o': 1.0, 'a': 156.004, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 38.4396, 'stlo': 30.9175, 'stel': 1140.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 195.58688, 'az': 114.40103, 'baz': 295.67456, 'gcarc': 1.7592269, 'depmen': 0.01961075, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 59, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'SDAG', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_2_0_BALB.BHZ.SAC
# 0
# 202009_2_25_KCTX.BHZ.SAC
# 4000
#          network: KO
#          station: KCTX
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:40:12.000000Z
#          endtime: 2020-09-19T20:40:51.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -280.9291, 'depmax': 281.85767, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 121.533, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.2627, 'stlo': 28.3353, 'stel': 445.0, 'evla': 39.141, 'evlo': 29.0235, 'evdp': 7.6, 'dist': 137.82182, 'az': 334.85992, 'baz': 154.42206, 'gcarc': 1.2397165, 'depmen': 0.06715223, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 40, 'nzsec': 2, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KCTX', 'kevnm': '20200919204037', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_2_43_ARMT.BHZ.SAC
# 4000
#          network: KO
#          station: ARMT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:40:08.000000Z
#          endtime: 2020-09-19T20:40:47.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -378.73883, 'depmax': 464.04272, 'b': 10.0, 'e': 49.989998, 'o': 7.0, 'a': 124.301, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.5683, 'stlo': 28.866, 'stel': 320.0, 'evla': 39.141, 'evlo': 29.0235, 'evdp': 7.6, 'dist': 159.05064, 'az': 355.1887, 'baz': 175.08817, 'gcarc': 1.4306839, 'depmen': -0.07014613, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 39, 'nzsec': 58, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'ARMT', 'kevnm': '20200919204037', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_2_9_KULA.BHZ.SAC
# 4000
#          network: KO
#          station: KULA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:40:07.000000Z
#          endtime: 2020-09-19T20:41:26.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
# ...
# 202009_19_82_ADVT.BHZ.SAC
# 4000
#          network: KO
#          station: ADVT
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:37:51.000000Z
#          endtime: 2020-09-19T20:38:30.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -217.91486, 'depmax': 202.96092, 'b': 10.0, 'e': 49.989998, 'o': 4.0, 'a': 94.353, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.4332, 'stlo': 29.7383, 'stel': 193.0, 'evla': 39.15683, 'evlo': 29.02717, 'evdp': 5.4, 'dist': 154.2529, 'az': 23.032255, 'baz': 203.4856, 'gcarc': 1.3875227, 'depmen': -0.06718244, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 37, 'nzsec': 41, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'ADVT', 'kevnm': '20200919203807', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_1_14_TVSB.BHZ.SAC
# 4000
#          network: KO
#          station: TVSB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-14T10:49:01.000000Z
#          endtime: 2020-09-14T10:49:40.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -168.91028, 'depmax': 156.53072, 'b': 10.0, 'e': 49.989998, 'o': 9.0, 'a': 109.149, 'internal0': 2.0, 't0': 115.164, 't1': 6.0149994, 'f': 0.0, 'stla': 39.4497, 'stlo': 29.4615, 'stel': 1090.0, 'evla': 39.16117, 'evlo': 29.0845, 'evdp': 8.0, 'dist': 45.646973, 'az': 45.31272, 'baz': 225.55054, 'gcarc': 0.41058818, 'depmen': 0.008891841, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 258, 'nzhour': 10, 'nzmin': 48, 'nzsec': 51, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'TVSB', 'kevnm': '20200914104940', 'khole': '--', 'ko': 'origin', 'ka': 'EPx22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_1_3_CAVI.BHZ.SAC
# 4000
#          network: KO
#          station: CAVI
#         location: --
#          channel: BHZ
#        starttime: 2020-09-14T10:49:09.000000Z
#          endtime: 2020-09-14T10:49:48.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -213.4617, 'depmax': 195.09268, 'b': 10.0, 'e': 49.989998, 'o': 1.0, 'a': 124.023, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.2018, 'stlo': 29.8377, 'stel': 670.0, 'evla': 39.16117, 'evlo': 29.0845, 'evdp': 8.0, 'dist': 132.38339, 'az': 28.97885, 'baz': 209.45786, 'gcarc': 1.190796, 'depmen': 0.047730807, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 258, 'nzhour': 10, 'nzmin': 48, 'nzsec': 59, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'CAVI', 'kevnm': '20200914104940', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_1_4_KULA.BHZ.SAC
# 4000
#          network: KO
#          station: KULA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-14T10:49:09.000000Z
#          endtime: 2020-09-14T10:50:28.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -212.86076, 'depmax': 224.08919, 'b': 10.0, 'e': 89.979996, 'o': 1.0, 'a': 114.095, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 38.5145, 'stlo': 28.6607, 'stel': 915.0, 'evla': 39.16117, 'evlo': 29.0845, 'evdp': 8.0, 'dist': 80.671104, 'az': 207.27155, 'baz': 27.006893, 'gcarc': 0.72560585, 'depmen': 0.014184637, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 258, 'nzhour': 10, 'nzmin': 48, 'nzsec': 59, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KULA', 'kevnm': '20200914104940', 'khole': '--', 'ko': 'origin', 'ka': 'EPx22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_1_9_KCTX.BHZ.SAC
# 4000
#          network: KO
#          station: KCTX
#         location: --
#          channel: BHZ
#        starttime: 2020-09-14T10:49:06.000000Z
#          endtime: 2020-09-14T10:49:45.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -191.57193, 'depmax': 203.495, 'b': 10.0, 'e': 49.989998, 'o': 4.0, 'a': 124.716, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.2627, 'stlo': 28.3353, 'stel': 445.0, 'evla': 39.16117, 'evlo': 29.0845, 'evdp': 8.0, 'dist': 138.15134, 'az': 332.52362, 'baz': 152.04686, 'gcarc': 1.2426813, 'depmen': 0.09989639, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 258, 'nzhour': 10, 'nzmin': 48, 'nzsec': 56, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KCTX', 'kevnm': '20200914104940', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_20_19_TVSB.BHZ.SAC
# 4000
#          network: KO
#          station: TVSB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-11T00:34:54.000000Z
#          endtime: 2020-09-11T00:35:33.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -52.939945, 'depmax': 51.824253, 'b': 10.0, 'e': 49.989998, 'o': 1.0, 'a': 100.605, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 39.4497, 'stlo': 29.4615, 'stel': 1090.0, 'evla': 38.9665, 'evlo': 28.9585, 'evdp': 5.3, 'dist': 69.03287, 'az': 38.846313, 'baz': 219.16296, 'gcarc': 0.6209375, 'depmen': -0.018692052, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 255, 'nzhour': 0, 'nzmin': 34, 'nzsec': 44, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'TVSB', 'kevnm': '20200911003528', 'khole': '--', 'ko': 'origin', 'ka': 'EP-32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_21_2_KULA.BHZ.SAC
# 4000
#          network: KO
#          station: KULA
#         location: --
#          channel: BHZ
#        starttime: 2020-09-20T23:42:05.000000Z
#          endtime: 2020-09-20T23:43:24.980000Z
#    sampling_rate: 50.0
#            delta: 0.02
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.02, 'depmin': -45.19973, 'depmax': 48.88333, 'b': 10.0, 'e': 89.979996, 'o': 5.0, 'a': 202.943, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 38.5145, 'stlo': 28.6607, 'stel': 915.0, 'evla': 39.14667, 'evlo': 29.01483, 'evdp': 13.4, 'dist': 76.62165, 'az': 203.77321, 'baz': 23.5521, 'gcarc': 0.6891823, 'depmen': 0.002885819, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 264, 'nzhour': 23, 'nzmin': 41, 'nzsec': 55, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'KULA', 'kevnm': '20200920234409', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_21_9_TVSB.BHZ.SAC
# 4000
#          network: KO
#          station: TVSB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-20T23:42:08.000000Z
#          endtime: 2020-09-20T23:42:47.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -121.91413, 'depmax': 131.08968, 'b': 10.0, 'e': 49.989998, 'o': 2.0, 'a': 199.157, 'internal0': 2.0, 't0': 205.177, 't1': 6.0200043, 'f': 0.0, 'stla': 39.4497, 'stlo': 29.4615, 'stel': 1090.0, 'evla': 39.14667, 'evlo': 29.01483, 'evdp': 13.4, 'dist': 51.15315, 'az': 48.735214, 'baz': 229.01695, 'gcarc': 0.46011528, 'depmen': -0.005018614, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 264, 'nzhour': 23, 'nzmin': 41, 'nzsec': 58, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'TVSB', 'kevnm': '20200920234409', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_22_113_HRTX.BHZ.SAC
# 4000
#          network: KO
#          station: HRTX
#         location: --
#          channel: BHZ
#        starttime: 2020-09-10T20:16:07.000000Z
#          endtime: 2020-09-10T20:16:46.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -140.88815, 'depmax': 168.68939, 'b': 10.0, 'e': 49.989998, 'o': 3.0, 'a': 155.464, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.801, 'stlo': 29.673, 'stel': 573.0, 'evla': 39.18533, 'evlo': 28.87733, 'evdp': 3.8, 'dist': 191.83557, 'az': 20.49306, 'baz': 201.00243, 'gcarc': 1.7256029, 'depmen': 0.10831271, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 254, 'nzhour': 20, 'nzmin': 15, 'nzsec': 57, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'HRTX', 'kevnm': '20200910201704', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_2_10_YLV.BHZ.SAC
# 4000
#          network: KO
#          station: YLV
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:40:07.000000Z
#          endtime: 2020-09-19T20:40:46.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -59.76473, 'depmax': 59.988956, 'b': 10.0, 'e': 49.989998, 'o': 8.0, 'a': 124.365, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.5658, 'stlo': 29.3708, 'stel': 879.0, 'evla': 39.141, 'evlo': 29.0235, 'evdp': 7.6, 'dist': 160.96855, 'az': 10.530048, 'baz': 190.75171, 'gcarc': 1.4479356, 'depmen': 0.016892197, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 39, 'nzsec': 57, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'YLV', 'kevnm': '20200919204037', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_2_2_YAYO.BHZ.SAC
# 4000
#          network: KO
#          station: YAYO
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:40:11.000000Z
#          endtime: 2020-09-19T20:40:50.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -167.77902, 'depmax': 171.2348, 'b': 10.0, 'e': 49.989998, 'o': 4.0, 'a': 126.226, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 39.6114, 'stlo': 27.0726, 'stel': 122.0, 'evla': 39.141, 'evlo': 29.0235, 'evdp': 7.6, 'dist': 176.03326, 'az': 287.8728, 'baz': 106.6401, 'gcarc': 1.5834012, 'depmen': -0.0016002064, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 40, 'nzsec': 1, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'YAYO', 'kevnm': '20200919204037', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_2_39_TVSB.BHZ.SAC
# 4000
#          network: KO
#          station: TVSB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:40:07.000000Z
#          endtime: 2020-09-19T20:40:46.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -220.02829, 'depmax': 241.75575, 'b': 10.0, 'e': 49.989998, 'o': 8.0, 'a': 106.173, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 39.4497, 'stlo': 29.4615, 'stel': 1090.0, 'evla': 39.141, 'evlo': 29.0235, 'evdp': 7.6, 'dist': 51.014153, 'az': 47.653683, 'baz': 227.92993, 'gcarc': 0.45886496, 'depmen': 0.0072088977, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 39, 'nzsec': 57, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'TVSB', 'kevnm': '20200919204037', 'khole': '--', 'ko': 'origin', 'ka': 'EPx22', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_2_42_SHUT.BHZ.SAC
# 0
# 202009_2_8_CAVI.BHZ.SAC
# 4000
#          network: KO
#          station: CAVI
#         location: --
#          channel: BHZ
#        starttime: 2020-09-19T20:40:05.000000Z
#          endtime: 2020-09-19T20:40:44.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -186.68637, 'depmax': 167.2181, 'b': 10.0, 'e': 49.989998, 'o': 10.0, 'a': 121.439995, 'internal0': 2.0, 't0': 0.002, 'f': 0.0, 'stla': 40.2018, 'stlo': 29.8377, 'stel': 670.0, 'evla': 39.141, 'evlo': 29.0235, 'evdp': 7.6, 'dist': 136.94156, 'az': 30.417124, 'baz': 210.93481, 'gcarc': 1.2317963, 'depmen': -0.02879224, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 263, 'nzhour': 20, 'nzmin': 39, 'nzsec': 55, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'CAVI', 'kevnm': '20200919204037', 'khole': '--', 'ko': 'origin', 'ka': 'EPx32', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})
# 202009_6_1_202009_2_25_KCTX.BHZ.SAC
# 889
# 202009_9_4_TVSB.BHZ.SAC
# 4000
#          network: KO
#          station: TVSB
#         location: --
#          channel: BHZ
#        starttime: 2020-09-21T08:11:09.000000Z
#          endtime: 2020-09-21T08:11:48.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 4000
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.01, 'depmin': -111.98744, 'depmax': 128.97707, 'b': 10.0, 'e': 49.989998, 'o': 1.0, 'a': 96.562, 'internal0': 2.0, 't0': 103.103, 't1': 6.5410004, 'f': 0.0, 'stla': 39.4497, 'stlo': 29.4615, 'stel': 1090.0, 'evla': 39.14567, 'evlo': 29.06467, 'evdp': 4.4, 'dist': 48.075695, 'az': 45.279194, 'baz': 225.52948, 'gcarc': 0.432434, 'depmen': 0.0031471758, 'cmpaz': 0.0, 'cmpinc': 0.0, 'nzyear': 2020, 'nzjday': 265, 'nzhour': 8, 'nzmin': 10, 'nzsec': 59, 'nzmsec': 0, 'nvhdr': 6, 'npts': 4000, 'iftype': 1, 'idep': 5, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 1, 'kstnm': 'TVSB', 'kevnm': '20200921081127', 'khole': '--', 'ko': 'origin', 'ka': 'EPx33', 'kt0': 'S', 'kf': 'D', 'kcmpnm': 'BHZ', 'knetwk': 'KO'})

# %%
from obspy import read, Trace, Stream
import os

path = "./"

folder_class = "class8"

files = []
for j, file in enumerate(os.listdir(path= path + folder_class)):
    files.append(file)

files = sorted(files)

for i, file in enumerate(files):
    print(file)
    trace = read(path + folder_class + "/" + file)[0]
    print(len(trace.data))

    if len(trace.data) == 4000:
        # print(trace.stats)
        trace.plot()
        # ix = input("Press Enter to continue...")
        # if ix == 'q':
        #     break
        
    else:
        print(len(trace.data))
        # os.remove(path + folder_class + "/" + file)

folder_class = "class7"


files = []
for j, file in enumerate(os.listdir(path= path + folder_class)):
    files.append(file)

files = sorted(files)

for i, file in enumerate(files):
    print(file)
    trace = read(path + folder_class + "/" + file)[0]
    print(len(trace.data))

    if len(trace.data) == 4000:
        # print(trace.stats)
        trace.plot()
        # ix = input("Press Enter to continue...")
        # if ix == 'q':
        #     break
        
    else:
        print(len(trace.data))
        # os.remove(path + folder_class + "/" + file)
# Out:
# 202007_10_49_GEDZ.BHZ.SAC
# 4000
# 202007_19_0_202007_10_49_GEDZ.BHZ.SAC
# 967
# 967
# 202007_10_86_MDNY.BHZ.SAC
# 4000
# 202007_15_1_202007_10_42_KCTX.BHZ.SAC
# 967
# 967

# %%
from obspy import read, Trace, Stream

path = "./class8/201905_3_0_SIMA.BHZ.SAC"

trace = read(path)[0]

print(trace.stats.endtime - trace.stats.starttime)
# trace.plot()

filtered = clean_sac_file(path, "")
# filtered.plot()

# %%
import os

# Define the directory path
dir_path = './'

for folder_month in os.listdir(dir_path):

    if not os.path.isfile(dir_path + folder_month):
        print(folder_month)

        for eartq in os.listdir(dir_path + folder_month):
            print(f"    {eartq}")
            
            for sac_file in os.listdir(dir_path + folder_month + '/' + eartq):
                print(f"        {sac_file}")
                # Define the input and output file paths
                input_file = dir_path + folder_month + '/' + eartq + '/' + sac_file
                output_file = dir_path + folder_month + '/' + eartq + '/' + sac_file[:-4] + '_filtered.sac'

                # Apply the clean_sac_file function
                trace_filtered = clean_sac_file(input_file, output_file)
                trace_filtered.plot()
                # trace_filtered.write(output_file, format='SAC')
            
                ix = input("Press Enter to continue...")

                if ix == 'q':
                    break

# %%
import glob

directory = './'  # Replace with the actual directory path you want to iterate over

# Find all items (files and directories) in the directory
items = glob.glob(directory + '/*')

# Iterate over the items
for item in items:
    if os.path.isfile(item):  # Check if the item is a file
        print(f"File: {os.path.basename(item)}")
    elif os.path.isdir(item):  # Check if the item is a directory
        print(f"Directory: {os.path.basename(item)}")
    else:
        print(f"Other: {os.path.basename(item)}")

# %%
# #  read sac file


# from obspy import read, Trace, Stream

# path = "./"
# folder_class = "class6"

# for j, file in enumerate(os.listdir(path= path + folder_class)):
#     print(file)
#     trace = read(path + folder_class + "/" + file)[0]
#     trace.plot()
#     ix = input("Press Enter to continue...")
#     if ix == 'q':
#         break
