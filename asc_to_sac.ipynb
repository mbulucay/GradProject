# %%
from obspy import Trace
import numpy as np

tr = Trace(data=np.arange(0, 10))
tr.stats.delta = 1.0
# tr._ltrim(tr.stats.starttime + 18)

tr.plot()

# %%
with open('./19990817000139_1404_mp_Acc_N.asc') as f:
    lines = f.readlines()

removed = []
[removed.append(x.replace('\n','')) for x in lines[64:]]

# %%
from obspy import Trace
import numpy as np

tr = Trace(data=np.array(removed))
tr.stats.delta = 1.0

tr.plot()

# %%
tr.write("out.sac", format="SAC")

# %%
# Out:
# 1 Trace(s) in Stream:
# ... | 1970-01-01T00:00:00.000000Z - 1970-01-01T00:54:17.000000Z | 1.0 Hz, 3258 samples
