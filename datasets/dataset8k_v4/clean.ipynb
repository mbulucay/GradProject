# %%
import os
from obspy import read

clean_class_folder = "class8/clean/"
clean_trace_file_list = []


for trace_file in os.listdir(clean_class_folder):
    clean_trace_file_list.append(str(trace_file))



original_class_folder = "class6/original/"
original_trace_file_list = []

for trace_file in os.listdir(original_class_folder):
    original_trace_file_list.append(str(trace_file))

original_trace_file_list.sort()
clean_trace_file_list.sort()

# %%
org = read(original_class_folder + original_trace_file_list[0])[0]
clean = read(clean_class_folder + clean_trace_file_list[0])[0]

print(original_trace_file_list[80])
org.plot()
print(clean_trace_file_list[80])
clean.plot()

# %%
clean_trace_file_list.sort()

# plot the original and clean traces
for i, trace in enumerate(clean_trace_file_list):
    print(f"clean trace: {i}: ", trace)
    read_clean_trace = read(clean_class_folder + trace)[0]
    read_clean_trace.plot()
    x = input("Enter q to quit:")
    if x == 'q':
        break

# %%
import os
from obspy import read

# plot the original and clean traces
for i, trace in enumerate(original_trace_file_list):
    print(f"original trace: {i} ", trace)
    
    read_original_trace = read(original_class_folder + trace)[0]
    read_original_trace.plot()

    read_clean_trace = read(clean_class_folder + clean_trace_file_list[i])[0]
    read_clean_trace.plot()

    x = input("Enter q to quit:")
    if x == 'q':
        break
# Out:
# original trace: 0  201901_10_46__GEDZ.BHZ.KO_original.sac
# original trace: 1  201901_13_0__SIMA.BHZ.KO_original.sac
# original trace: 2  201901_1_39__GEDZ.BHZ.KO_original.sac
# original trace: 3  201901_22_0__SIMA.BHZ.KO_original.sac
# original trace: 4  201902_1_110__ARMT.BHZ.KO_original.sac
# original trace: 5  201902_1_147__MDNY.BHZ.KO_original.sac
# original trace: 6  201902_1_84__GEDZ.BHZ.KO_original.sac
# original trace: 7  201903_13_41__GEDZ.BHZ.KO_original.sac
# original trace: 8  201903_14_0__SIMA.BHZ.KO_original.sac
# original trace: 9  201903_9_32__GEDZ.BHZ.KO_original.sac
# original trace: 10  201904_11_0__SIMA.BHZ.KO_original.sac
# original trace: 11  201904_8_0__SIMA.BHZ.KO_original.sac
# original trace: 12  201905_0_21__GEDZ.BHZ.KO_original.sac
# original trace: 13  201905_18_0__SIMA.BHZ.KO_original.sac
# original trace: 14  201905_1_0__SIMA.BHZ.KO_original.sac
# original trace: 15  201905_2_0__SIMA.BHZ.KO_original.sac
# ...
