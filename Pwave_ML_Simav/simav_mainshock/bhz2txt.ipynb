# %%
import os
from obspy.core import read


dir_path = '.'
save_path = './text_data'

for file_name in os.listdir(dir_path):

    if os.path.isfile(os.path.join(dir_path, file_name)) and os.path.join(dir_path, file_name).format().endswith("BHZ"):
        print(file_name)
        
        track = read(os.path.join(dir_path, file_name))
        track.plot()

        with open(os.path.join(save_path, file_name.replace(".BHZ", ".txt")), 'w') as f:
            for nth,data in enumerate(track[0].data):
                f.write(str(data))
                if(nth+1 != len(track[0].data)):
                    f.write(' ')
# Out:
# 2011-05192010_GULT.BHZ
# 2011-05192010_ARMT.BHZ
# 2011-05192010_DKL.BHZ
# 2011-05192010_HRTX.BHZ
# 2011-05192010_ESPY.BHZ
# 2011-05192010_GEMT.BHZ
# 2011-05192010_GONE.BHZ
# 2011-05192010_GELI.BHZ
# 2011-05192010_KONT.BHZ
# 2011-05192010_SERE.BHZ
# 2011-05192010_MAZI.BHZ
# 2011-05192010_ERIK.BHZ
# 2011-05192010_CTKS.BHZ
# 2011-05192010_KDZE.BHZ
# 2011-05192010_DARE.BHZ
# 2011-05192010_SILT.BHZ
# 2011-05192010_SVRH.BHZ
# 2011-05192010_SVRC.BHZ
# 2011-05192010_EDRB.BHZ
# 2011-05192010_BNGB.BHZ
# 2011-05192010_CORM.BHZ
# 2011-05192010_TAHT.BHZ
# 2011-05192010_DIKM.BHZ
# 2011-05192010_RSDY.BHZ
# 2011-05192013_CALI.BHZ
# 2011-05192010_CAVI.BHZ
# 2011-05192010_CUKT.BHZ
# 2011-05192010_MDUB.BHZ
# 2011-05192010_ADVT.BHZ
# 2011-05192010_ERZN.BHZ
# 2011-05192010_BALB.BHZ
# 2011-05192010_YKAV.BHZ
# 2011-05192010_AYDB.BHZ
# 2011-05192010_KUSD.BHZ
# 2011-05192010_SNOP.BHZ
# 2011-05192010_GPNR.BHZ
# 2011-05192010_GAZ.BHZ
# 2011-05192010_CTYL.BHZ
# 2011-05192013_BBDE.BHZ
# 2011-05192010_YEDI.BHZ
# 2011-05192010_DATC.BHZ
# 2011-05192010_ILIC.BHZ
# 2011-05192010_CANT.BHZ
# 2011-05192010_DALY.BHZ
# 2011-05192010_BGKT.BHZ
# 2011-05192010_MERS.BHZ
# 2011-05192010_PHSR.BHZ
# 2011-05192013_SULE.BHZ
# 2011-05192010_GLHS.BHZ
# 2011-05192010_KCTX.BHZ
# 2011-05192010_KLYT.BHZ
# 2011-05192010_DIDI.BHZ
# 2011-05192010_KIYI.BHZ
# 2011-05192010_KRTS.BHZ
# 2011-05192010_KARA.BHZ
# 2011-05192010_GULA.BHZ
# 2011-05192010_SUTC.BHZ
# 2011-05192010_KRBG.BHZ
# 2011-05192010_KARS.BHZ
# 2011-05192010_TVSB.BHZ
# 2011-05192010_CHBY.BHZ
# 2011-05192013_YENE.BHZ
# 2011-05192010_CEYT.BHZ
# 2011-05192010_DYBB.BHZ
# 2011-05192010_ENZZ.BHZ
# 2011-05192010_FETY.BHZ
# 2011-05192010_ENEZ.BHZ
# 2011-05192010_SENK.BHZ
# 2011-05192010_URFA.BHZ
# 2011-05192010_SVSK.BHZ
# 2011-05192010_GOKC.BHZ
# 2011-05192010_IDI.BHZ
# 2011-05192010_BAYT.BHZ
# 2011-05192010_SLVT.BHZ
# 2011-05192010_KTUT.BHZ
# 2011-05192010_MRMT.BHZ
# 2011-05192010_MRSB.BHZ
# 2011-05192010_MDNY.BHZ
# 2011-05192010_BODT.BHZ
# 2011-05192010_CRLT.BHZ
# 2011-05192013_GBZM.BHZ
# 2011-05192010_CLDR.BHZ
# 2011-05192010_ANTB.BHZ
# 2011-05192010_LADK.BHZ

# %%
# Import the clean_sac_file function from the previous example
from obspy import read, Trace, Stream
from obspy.signal.filter import bandpass

def clean_sac_file(input_file, output_file, freq_min, freq_max):
    """
    Applies a bandpass filter to a SAC file to clean noise.

    Inputs:
    - input_file: path to the input SAC file
    - output_file: path to the output SAC file
    - freq_min: minimum frequency of the passband in Hz
    - freq_max: maximum frequency of the passband in Hz
    """
    # Read in the SAC file as an ObsPy Trace object
    trace = read(input_file)[0]

    # Apply a bandpass filter to the trace
    trace_filtered = trace.copy()
    trace_filtered.data = bandpass(trace.data, freqmin=freq_min, freqmax=freq_max, df=trace.stats.sampling_rate)

    # Write the filtered trace to a new SAC file
    trace_filtered.write(output_file, format='SAC')

# Test the clean_sac_file function on an example SAC file
input_file = "./MDNY.BHZ.KO"
output_file = "example_filtered2.sac"
freq_min = 0.5
freq_max = 250.0
clean_sac_file(input_file, output_file, freq_min, freq_max)

# Verify that the filtered SAC file was created
trace_filtered = read(output_file)[0]
print(trace_filtered)


clean_sac_file = read("./example_filtered2.sac")
clean_sac_file.plot()
# Out:
# KO.MDNY.--.BHZ | 2022-01-03T04:13:55.000000Z - 2022-01-03T04:17:24.990000Z | 100.0 Hz, 21000 samples
