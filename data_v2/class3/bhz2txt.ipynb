# %%
import os
from obspy.core import read
from obspy.signal.trigger import classic_sta_lta
from obspy.signal.trigger import plot_trigger
from obspy.signal.trigger import z_detect
from obspy.signal.trigger import recursive_sta_lta
import shutil

os.makedirs("class1")
os.makedirs("class2")
os.makedirs("class3")

dir_path = '.'
date = "v2"

for file_name in os.listdir(dir_path):

    if os.path.isfile(os.path.join(dir_path, file_name)) and os.path.join(dir_path, file_name).format().__contains__("BHZ"):
        print(file_name)
        
        stream = read(os.path.join(dir_path, file_name))
        trace = stream[0]
        trace.plot()

        # get integer input
        a = int(input("Enter 1 2"))
        if a == 1:
            shutil.copy2(file_name, './class1/' + date + file_name)
        elif a == 2:
            shutil.copy2(file_name, './class2/' + date + file_name)
        else:
            shutil.copy2(file_name, './class3/' + date + file_name)

        # df = trace.stats.sampling_rate
        # cft = recursive_sta_lta(trace.data, int(5 * df), int(10 * df))
        # plot_trigger(trace, cft, 1.2, 0.5)

        # with open(os.path.join(save_path, file_name.replace(".KO", ".txt")), 'w') as f:
        #     for nth,data in enumerate(trace.data):
        #         f.write(str(data))
        #         if(nth+1 != len(trace.data)):
        #             f.write(' ')
# Out:
# 15_10_22GEML.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 09_08_22MDNY.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 07_05_22KULA.BHZ.SAC
# 01_22_22GEDZ.BHZ.SAC
# 02_10_22TVSB.BHZ.SAC
# 11_08_22BAKL.BHZ.SAC
# 01_10_22KULA.BHZ.SAC
# 06_05_22KO.KULA..BHZ.D.2022.143.183356.SAC
# 09_08_22KULA.BHZ.SAC
# 05_05_22BAKL.BHZ.SAC
# 02_11_22KULA.BHZ.SAC
# 02_10_22GEDZ.BHZ.SAC
# 05_08_22GEDZ.BHZ.SAC
# 07_08_22TVSB.BHZ.SAC
# 07_10_22KULA.BHZ.SAC
# 13_08_22TVSB.BHZ.SAC
# 01_07_22TVSB.BHZ.SAC
# 01_07_22GULT.BHZ.SAC
# 04_02_21TVSB.BHZ.SAC
# 08_08_22GEDZ.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 03_02_21GEDZ.BHZ.SAC
# 02_02_21GAZK.BHZ.SAC
# 02_09_22GEDZ.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 04_07_22KULA.BHZ.SAC
# 02_05_22SIMA.BHZ.SAC
# 02_09_22TVSB.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 07_08_22MDNY.BHZ.SAC
# 01_09_22TVSB.BHZ.SAC
# 01_07_22SHUT.BHZ.SAC
# 01_02_21TVSB.BHZ.SAC
# 08_10_22KULA.BHZ.SAC
# 07_10_22MDNY.BHZ.SAC
# 05_22_22GEDZ.BHZ.SAC
# 07_10_22GEDZ.BHZ.SAC
# 09_08_22TVSB.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 07_10_22GULT.BHZ.SAC
# 04_08_22TVSB.BHZ.SAC
# 02_01_21MDNY.BHZ.SAC
# 06_10_22KULA.BHZ.SAC
# 04_02_21ARMT.BHZ.SAC
# 01_07_22APMY.BHZ.SAC
# 03_05_22SIMA.BHZ.SAC
# 13_08_22GEDZ.BHZ.SAC
# 13_10_22KULA.BHZ.SAC
# 04_07_22SIMA.BHZ.SAC
# 13_10_22GEDZ.BHZ.SAC
# 02_08_22MDNY.BHZ.SAC
# 04_22_22BAKL.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 02_08_22KULA.BHZ.SAC
# 02_05_22GEDZ.BHZ.SAC
# 01_11_22TVSB.BHZ.SAC
# 04_04_22GEDZ.BHZ.SAC
# 12_10_22KULA.BHZ.SAC
# 04_02_21SIMA.BHZ.SAC
# 05_02_21TVSB.BHZ.SAC
# 11_08_22SHUT.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 02_11_22GEDZ.BHZ.SAC
# 06_01_21SIMA.BHZ.SAC
# 01_07_22BAKL.BHZ.SAC
# 01_05_22TVSB.BHZ.SAC
# 12_08_22MDNY.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 07_08_22KULA.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 02_11_22ADVT.BHZ.SAC
# 02_08_22TVSB.BHZ.SAC
# 03_01_21KO.KULA..BHZ.D.2021.012.185043.SAC
# 01_10_22GEDZ.BHZ.SAC
# 01_05_22KULA.BHZ.SAC
# 03_05_22TVSB.BHZ.SAC
# 01_11_22MDNY.BHZ.SAC
# 01_07_22KULA.BHZ.SAC
# 08_08_22MDNY.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 03_06_22GEDZ.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 04_05_22GEDZ.BHZ.SAC
# 14_10_22GEML.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 01_05_22YAYO.BHZ.SAC
# 04_07_22TVSB.BHZ.SAC
# 03_09_22CAVI.BHZ.SAC
# 02_05_22SHUT.BHZ.SAC
# 11_08_22CAVI.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 07_10_22BAKL.BHZ.SAC
# 02_02_21TVSB.BHZ.SAC
# 01_03_22GEDZ.BHZ.SAC
# 02_09_22BAKL.BHZ.SAC
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/maintain/.local/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# 01_11_22GEML.BHZ.SAC
# 04_02_21GEML.BHZ.SAC
# 02_01_21KULA.BHZ.SAC
# 07_22_22GEDZ.BHZ.SAC
# 05_02_21KULA.BHZ.SAC
# 03_08_22GEDZ.BHZ.SAC
# 05_05_22KCTX.BHZ.SAC

# %%
# Import the clean_sac_file function from the previous example
from obspy import read, Trace, Stream
from obspy.signal.filter import bandpass

def clean_sac_file(input_file, output_file, freq_min, freq_max):
    """
    Applies a bandpass filter to a SAC file to clean noise.

    Inputs:
    - input_file: path to the input SAC file
    - output_file: path to the output SAC file
    - freq_min: minimum frequency of the passband in Hz
    - freq_max: maximum frequency of the passband in Hz
    """
    # Read in the SAC file as an ObsPy Trace object
    trace = read(input_file)[0]

    # Apply a bandpass filter to the trace
    trace_filtered = trace.copy()
    trace_filtered.data = bandpass(trace.data, freqmin=freq_min, freqmax=freq_max, df=trace.stats.sampling_rate)

    # Write the filtered trace to a new SAC file
    trace_filtered.write(output_file, format='SAC')

# Test the clean_sac_file function on an example SAC file
input_file = "./GEDZ.BHZ.KO"
output_file = "example_filtered2.sac"
freq_min = 10.0
freq_max = 100.0
clean_sac_file(input_file, output_file, freq_min, freq_max)

# Verify that the filtered SAC file was created
trace_filtered = read(output_file)[0]
print(trace_filtered)


clean_sac_file = read(output_file)
clean_sac_file.plot()
# Out:
# /home/maintain/.local/lib/python3.10/site-packages/obspy/signal/filter.py:62: UserWarning: Selected high corner frequency (100.0) of bandpass is at or above Nyquist (50.0). Applying a high-pass instead.
#   warnings.warn(msg)
# KO.GEDZ.--.BHZ | 2022-02-10T12:28:58.000000Z - 2022-02-10T12:33:12.990000Z | 100.0 Hz, 25500 samples
